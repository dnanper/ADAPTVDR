# %%
import pandas as pd
import polars as pl

# %%
data = pl.read_parquet("dataset/triplets-en/train-00000-of-00006.parquet")
data
# Out:
# shape: (10_000, 3)
# ┌────────────────────────────────┬────────────────────────────────┬────────────────────────────────┐
# │ query                          ┆ positive                       ┆ hard_negatives                 │
# │ ---                            ┆ ---                            ┆ ---                            │
# │ str                            ┆ binary                         ┆ list[binary]                   │
# ╞════════════════════════════════╪════════════════════════════════╪════════════════════════════════╡
# │ What are the new               ┆ b"\xff\xd8\xff\xe0\x00\x10JFIF ┆ [b"\xff\xd8\xff\xe0\x00\x10JFI │
# │ anthropologic…                 ┆ …                              ┆ …                              │
# │ What are the three main        ┆ b"\xff\xd8\xff\xe0\x00\x10JFIF ┆ [b"\xff\xd8\xff\xe0\x00\x10JFI │
# │ positi…                        ┆ …                              ┆ …                              │
# ...

# %%
bench = pd.read_csv("results/vidore_colqwen3_5.csv")
bench
# Out:
#            subset  dims  n_queries  n_docs  ndcg@5  recall@1  recall@5  \
# 0         arxivqa   128      500.0   500.0  0.8176    0.7520    0.8720
# 1         arxivqa   256      500.0   500.0  0.8322    0.7800    0.8740
# 2         arxivqa   512      500.0   500.0  0.8418    0.7840    0.8920
# 3         arxivqa  1024      500.0   500.0  0.8462    0.7920    0.8920
# 4          docvqa   128      500.0   500.0  0.5421    0.4500    0.6220
# 5          docvqa   256      500.0   500.0  0.5588    0.4700    0.6380
# 6          docvqa   512      500.0   500.0  0.5640    0.4740    0.6420
# 7          docvqa  1024      500.0   500.0  0.5675    0.4820    0.6440
# 8         infovqa   128      500.0   500.0  0.8782    0.8240    0.9200
# 9         infovqa   256      500.0   500.0  0.8885    0.8440    0.9280
# 10        infovqa   512      500.0   500.0  0.8940    0.8500    0.9300
# 11        infovqa  1024      500.0   500.0  0.9034    0.8700    0.9320
# ...
